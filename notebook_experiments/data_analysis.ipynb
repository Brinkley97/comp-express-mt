# %% [markdown]
# # Data Analysis

# %%
import os
import sys

import pandas as pd

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../utils'))

from data_processing import DataProcessing

# %%
pd.set_option('max_colwidth', 800)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
file_name = "akuapem_dataset - gold_standard.csv"
path = os.path.join("../data/", file_name)

df = DataProcessing.load_data(path)
df.head(7)
# Out:
#                      Unnamed: 0                Akuapem  Unnamed: 2  \
# 0                I belong here.         Me na mewɔ ha.         NaN
# 1                           NaN     Me fata sɛ mewɔ ha         NaN
# 2                           NaN            ha na me wɔ         NaN
# 3       Kwaku sings quite well.    Kwaku to dwom yiye.         NaN
# 4                           NaN      Kwaku nim nwom to         NaN
# 5  He calls her up every night.  Anadwo biara ɔfrɛ no          NaN
# 6                           NaN  ɔfrɛ no anadwo biara          NaN
#
#                Akuapem                     English
# 0  Anadwo biara ɔfrɛ no   He calls her every night
# 1                   NaN   He calls him every night
# 2                   NaN  She calls her every night
# 3                   NaN   He calls her every night
# 4  Anɔpa yi, ohyiaa no.  She met him this morning
# 5                   NaN  She met her this morning
# 6                   NaN    He met her this morning

# %%
cols_to_drop = ['Unnamed: 2']
DataProcessing.drop_data_from_df(df, cols_to_drop)
# Out:
#                   Unnamed: 0                          Akuapem  \
# 0             I belong here.                   Me na mewɔ ha.
# 1                        NaN               Me fata sɛ mewɔ ha
# 2                        NaN                      ha na me wɔ
# 3    Kwaku sings quite well.              Kwaku to dwom yiye.
# 4                        NaN                Kwaku nim nwom to
# ..                       ...                              ...
# 687                      NaN                      S[n na [te
# 688                      NaN                    Ne su te s[n?
# 689      I ran out of ideas.              Ná minhu nea menyɛ.
# 690                      NaN                  Me nsusui[ asa
# 691                      NaN  Menni tirimp]/adwene biara bio
#
#                  Akuapem                     English
# 0    Anadwo biara ɔfrɛ no   He calls her every night
# 1                     NaN   He calls him every night
# 2                     NaN  She calls her every night
# ...

# %%
one_to_many_cols = [0, 1]
one_to_many_df = DataProcessing.split_df_mappings(df, one_to_many_cols)
one_to_many_df
# Out:
#                   Unnamed: 0                          Akuapem
# 0             I belong here.                   Me na mewɔ ha.
# 1                        NaN               Me fata sɛ mewɔ ha
# 2                        NaN                      ha na me wɔ
# 3    Kwaku sings quite well.              Kwaku to dwom yiye.
# 4                        NaN                Kwaku nim nwom to
# ..                       ...                              ...
# 687                      NaN                      S[n na [te
# 688                      NaN                    Ne su te s[n?
# 689      I ran out of ideas.              Ná minhu nea menyɛ.
# 690                      NaN                  Me nsusui[ asa
# 691                      NaN  Menni tirimp]/adwene biara bio
#
# [692 rows x 2 columns]

# %%
many_to_one_cols = [2, 3]
many_to_one_df = DataProcessing.split_df_mappings(df, many_to_one_cols)
many_to_one_df
# Out:
#                  Akuapem                     English
# 0    Anadwo biara ɔfrɛ no   He calls her every night
# 1                     NaN   He calls him every night
# 2                     NaN  She calls her every night
# 3                     NaN   He calls her every night
# 4    Anɔpa yi, ohyiaa no.  She met him this morning
# ..                    ...                        ...
# 687                   NaN                        NaN
# 688                   NaN                        NaN
# 689                   NaN                        NaN
# 690                   NaN                        NaN
# 691                   NaN                        NaN
#
# [692 rows x 2 columns]

# %%
cols_to_rename = {"Unnamed: 0": "English (Source, One)", 
                  "Akuapem": "Akan (Target, Many)"
                  }
DataProcessing.rename_df_cols(one_to_many_df, cols_to_rename)
# Out:
# /Users/detraviousjamaribrinkley/Documents/Development/classes/cai_6307_nlp/comp_express_mt/notebook_experiments/../utils/data_processing.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=cols, inplace=True)
#        English (Source, One)              Akan (Target, Many)
# 0             I belong here.                   Me na mewɔ ha.
# 1                        NaN               Me fata sɛ mewɔ ha
# 2                        NaN                      ha na me wɔ
# 3    Kwaku sings quite well.              Kwaku to dwom yiye.
# 4                        NaN                Kwaku nim nwom to
# ..                       ...                              ...
# 687                      NaN                      S[n na [te
# 688                      NaN                    Ne su te s[n?
# ...

# %%
cols_to_rename = {"Akuapem ": "Akan (Target, Many)", 
                  "English": "English (Target, Many)"
                  }
DataProcessing.rename_df_cols(many_to_one_df, cols_to_rename)
# Out:
# /Users/detraviousjamaribrinkley/Documents/Development/classes/cai_6307_nlp/comp_express_mt/notebook_experiments/../utils/data_processing.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=cols, inplace=True)
#       Akan (Target, Many)     English (Target, Many)
# 0    Anadwo biara ɔfrɛ no   He calls her every night
# 1                     NaN   He calls him every night
# 2                     NaN  She calls her every night
# 3                     NaN   He calls her every night
# 4    Anɔpa yi, ohyiaa no.  She met him this morning
# ..                    ...                        ...
# 687                   NaN                        NaN
# 688                   NaN                        NaN
# 689                   NaN                        NaN
# ...

# %%
one_to_many_pt = DataProcessing.df_to_pivot_table(one_to_many_df, 'English (Source, One)', ["English (Source, One)", "Akan (Target, Many)"])
one_to_many_pt
# Out:
# /Users/detraviousjamaribrinkley/Documents/Development/classes/cai_6307_nlp/comp_express_mt/notebook_experiments/../utils/data_processing.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_to_update] = DataProcessing.fill_na_with_value(df, col_to_update)
# Empty DataFrame
# Columns: []
# ...

# %%
one_to_many_pt
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
DataProcessing.drop_data_from_df(one_to_many_pt, dropna=True)
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# ### NaN exists in Akan (Target, Many)

# %%
one_to_many_df.iloc[: , [1]]
# Out:
#                  Akan (Target, Many)
# 0                     Me na mewɔ ha.
# 1                 Me fata sɛ mewɔ ha
# 2                        ha na me wɔ
# 3                Kwaku to dwom yiye.
# 4                  Kwaku nim nwom to
# ..                               ...
# 687                      S[n na [te
# 688                    Ne su te s[n?
# 689              Ná minhu nea menyɛ.
# 690                  Me nsusui[ asa
# 691  Menni tirimp]/adwene biara bio
#
# [692 rows x 1 columns]

# %%
one_to_many_df.iloc[: , [1]].dropna()
# Out:
#                  Akan (Target, Many)
# 0                     Me na mewɔ ha.
# 1                 Me fata sɛ mewɔ ha
# 2                        ha na me wɔ
# 3                Kwaku to dwom yiye.
# 4                  Kwaku nim nwom to
# ..                               ...
# 687                      S[n na [te
# 688                    Ne su te s[n?
# 689              Ná minhu nea menyɛ.
# 690                  Me nsusui[ asa
# 691  Menni tirimp]/adwene biara bio
#
# [399 rows x 1 columns]

# %% [markdown]
# ### No NaN in English (Source, One)

# %%
one_to_many_df.iloc[: , [0]]
# Out:
#        English (Source, One)
# 0             I belong here.
# 1             I belong here.
# 2             I belong here.
# 3    Kwaku sings quite well.
# 4    Kwaku sings quite well.
# ..                       ...
# 687          What's it like?
# 688          What's it like?
# 689      I ran out of ideas.
# 690      I ran out of ideas.
# 691      I ran out of ideas.
#
# [692 rows x 1 columns]

# %%
one_to_many_df.iloc[: , [0]].dropna()
# Out:
#        English (Source, One)
# 0             I belong here.
# 1             I belong here.
# 2             I belong here.
# 3    Kwaku sings quite well.
# 4    Kwaku sings quite well.
# ..                       ...
# 687          What's it like?
# 688          What's it like?
# 689      I ran out of ideas.
# 690      I ran out of ideas.
# 691      I ran out of ideas.
#
# [692 rows x 1 columns]
