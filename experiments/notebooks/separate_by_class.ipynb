# %% [markdown]
# # Data Analysis

# %%
import os
import sys

import pandas as pd

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../../utils'))

from data_processing import DataProcessing

# %%
pd.set_option('max_colwidth', 800)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
file_name = "akuapem_with_tags_dataset-verified_data.xlsx"
path = os.path.join("../../data/tagged_data", file_name)

# %%
### ONE TO MANY ###
one_to_many_df = pd.read_excel(path, sheet_name="1-M_tags")
akan_source_one = "Akan (Source, One)"
eng_target_many = "English (Target, Many)"
one_many_cols_to_rename = {"Akuapem Twi": akan_source_one, 
                  "English": eng_target_many
                  }
one_to_many_df.rename(columns=one_many_cols_to_rename, inplace=True)
one_to_many_df
# Out:
#         AUD_SIZE  STATUS   AGE FORMALITY     GENDER   GENDER_2    ANIMACY  \
# 0     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
# 1     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE  MASCULINE    ANIMATE
# 2     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE   FEMININE    ANIMATE
# 3     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
# 4     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE  MASCULINE    ANIMATE
# ..           ...     ...   ...       ...        ...        ...        ...
# 458   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
# 459   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
# 460  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
# 461  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
# 462  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#
#     SPEECH_ACT                                Akan (Source, One)  \
# 0    STATEMENT                             Anadwo biara ɔfrɛ no.
# 1    STATEMENT                             Anadwo biara ɔfrɛ no.
# 2    STATEMENT                             Anadwo biara ɔfrɛ no.
# 3    STATEMENT                             Anadwo biara ɔfrɛ no.
# 4    STATEMENT                              Anɔpa yi, ohyiaa no.
# ..         ...                                               ...
# 458  STATEMENT                            Nokwarem no, osu bɛtɔ.
# 459  STATEMENT                            Nokwarem no, osu bɛtɔ.
# 460  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
# 461  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
# 462  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#
#                           English (Target, Many)
# 0                      He calls her every night.
# 1                      He calls him every night.
# 2                     She calls her every night.
# 3                      He calls her every night.
# 4                      She met him this morning.
# ..                                           ...
# 458              It is definitely going to rain.
# 459                   Rain is surely on the way.
# 460          We've got to find a new babysitter.
# 461      We need to look for another babysitter.
# 462  It is necessary we find another babysitter.
#
# [463 rows x 10 columns]

# %%
# sheet_names = ["1-M_tags", "M-1_tags"]

# %%
one_to_many_df = pd.read_excel(path, sheet_name="1-M_tags")
eng_source_one = "English (Target, Many)"
akan_target_many = "Akan (Source, One)"
cols_to_rename = {"English": eng_source_one, 
                  "Akuapem Twi": akan_target_many
                  }
one_to_many_df.rename(columns=cols_to_rename, inplace=True)
one_to_many_df
# Out:
#         AUD_SIZE  STATUS   AGE FORMALITY     GENDER   GENDER_2    ANIMACY  \
# 0     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
# 1     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE  MASCULINE    ANIMATE
# 2     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE   FEMININE    ANIMATE
# 3     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
# 4     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE  MASCULINE    ANIMATE
# ..           ...     ...   ...       ...        ...        ...        ...
# 458   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
# 459   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
# 460  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
# 461  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
# 462  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#
#     SPEECH_ACT                                Akan (Source, One)  \
# 0    STATEMENT                             Anadwo biara ɔfrɛ no.
# 1    STATEMENT                             Anadwo biara ɔfrɛ no.
# 2    STATEMENT                             Anadwo biara ɔfrɛ no.
# 3    STATEMENT                             Anadwo biara ɔfrɛ no.
# 4    STATEMENT                              Anɔpa yi, ohyiaa no.
# ..         ...                                               ...
# 458  STATEMENT                            Nokwarem no, osu bɛtɔ.
# 459  STATEMENT                            Nokwarem no, osu bɛtɔ.
# 460  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
# 461  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
# 462  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#
#                           English (Target, Many)
# 0                      He calls her every night.
# 1                      He calls him every night.
# 2                     She calls her every night.
# 3                      He calls her every night.
# 4                      She met him this morning.
# ..                                           ...
# 458              It is definitely going to rain.
# 459                   Rain is surely on the way.
# 460          We've got to find a new babysitter.
# 461      We need to look for another babysitter.
# 462  It is necessary we find another babysitter.
#
# [463 rows x 10 columns]

# %%
### MANY TO ONE ###
many_to_one_df = pd.read_excel(path, sheet_name="M-1_tags")
akan_source_one = "Akan (Source, Many)"
eng_target_many = "English (Target, One)"
many_one_cols_to_rename = {"Akuapem Twi": akan_source_one, 
                  "English": eng_target_many
                  }
many_to_one_df.rename(columns=many_one_cols_to_rename, inplace=True)
many_to_one_df
# Out:
#        AUD_SIZE STATUS    AGE FORMALITY     GENDER GENDER.1  ANIMACY  \
# 0    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 1    INDIVIDUAL  EQUAL   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 2    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 3    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
# 4    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
# ..          ...    ...    ...       ...        ...      ...      ...
# 395  INDIVIDUAL    NaN  ELDER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 396  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 397  INDIVIDUAL    NaN   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 398  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
# 399  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#
#     SPEECH_ACT       Akan (Source, Many)    English (Target, One)
# 0    STATEMENT            Me na mewɔ ha.           I belong here.
# 1       ANSWER       Me fata sɛ mewɔ ha.           I belong here.
# 2    STATEMENT              Ha na me wɔ.           I belong here.
# 3    STATEMENT       Kwaku to dwom yiye.  Kwaku sings quite well.
# 4    STATEMENT        Kwaku nim nwom to.  Kwaku sings quite well.
# ..         ...                       ...                      ...
# 395   QUESTION             Ne su te sɛn?          What's it like?
# 396  STATEMENT       Na minhu nea menyɛ.      I ran out of ideas.
# 397  STATEMENT           Me nsusuiɛ asa.      I ran out of ideas.
# 398  STATEMENT   Menni adwene biara bio.      I ran out of ideas.
# 399  STATEMENT  Menni tirimpɔ biara bio.      I ran out of ideas.
#
# [400 rows x 10 columns]

# %%
stats = {}
stats["1-M_df"] = one_to_many_df
stats["M-1_df"] = many_to_one_df
stats
# Out:
# {'1-M_df':         AUD_SIZE  STATUS   AGE FORMALITY     GENDER   GENDER_2    ANIMACY  \
#  0     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
#  1     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE  MASCULINE    ANIMATE
#  2     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE   FEMININE    ANIMATE
#  3     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
#  4     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE  MASCULINE    ANIMATE
#  ..           ...     ...   ...       ...        ...        ...        ...
#  458   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
#  459   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
#  460  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#  461  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#  462  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#
#      SPEECH_ACT                                Akan (Source, One)  \
#  0    STATEMENT                             Anadwo biara ɔfrɛ no.
#  1    STATEMENT                             Anadwo biara ɔfrɛ no.
#  2    STATEMENT                             Anadwo biara ɔfrɛ no.
#  3    STATEMENT                             Anadwo biara ɔfrɛ no.
#  4    STATEMENT                              Anɔpa yi, ohyiaa no.
#  ..         ...                                               ...
#  458  STATEMENT                            Nokwarem no, osu bɛtɔ.
#  459  STATEMENT                            Nokwarem no, osu bɛtɔ.
#  460  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#  461  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#  462  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#
#                            English (Target, Many)
#  0                      He calls her every night.
#  1                      He calls him every night.
#  2                     She calls her every night.
#  3                      He calls her every night.
#  4                      She met him this morning.
#  ..                                           ...
#  458              It is definitely going to rain.
#  459                   Rain is surely on the way.
#  460          We've got to find a new babysitter.
#  461      We need to look for another babysitter.
#  462  It is necessary we find another babysitter.
#
#  [463 rows x 10 columns],
#  'M-1_df':        AUD_SIZE STATUS    AGE FORMALITY     GENDER GENDER.1  ANIMACY  \
#  0    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  1    INDIVIDUAL  EQUAL   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  2    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  3    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
#  4    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
#  ..          ...    ...    ...       ...        ...      ...      ...
#  395  INDIVIDUAL    NaN  ELDER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  396  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  397  INDIVIDUAL    NaN   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  398  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  399  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#
#      SPEECH_ACT       Akan (Source, Many)    English (Target, One)
#  0    STATEMENT            Me na mewɔ ha.           I belong here.
#  1       ANSWER       Me fata sɛ mewɔ ha.           I belong here.
#  2    STATEMENT              Ha na me wɔ.           I belong here.
#  3    STATEMENT       Kwaku to dwom yiye.  Kwaku sings quite well.
#  4    STATEMENT        Kwaku nim nwom to.  Kwaku sings quite well.
#  ..         ...                       ...                      ...
#  395   QUESTION             Ne su te sɛn?          What's it like?
#  396  STATEMENT       Na minhu nea menyɛ.      I ran out of ideas.
#  397  STATEMENT           Me nsusuiɛ asa.      I ran out of ideas.
#  398  STATEMENT   Menni adwene biara bio.      I ran out of ideas.
#  399  STATEMENT  Menni tirimpɔ biara bio.      I ran out of ideas.
#
#  [400 rows x 10 columns]}

# %%
# # what your speech can make someone do
# SPEECH_ACT_COL_NAME = 'SPEECH_ACT'
# speech_act_entries = many_to_one_df[SPEECH_ACT_COL_NAME].unique()
# speech_act_entries

# %%
def separate_by_entry(df, col_name, entry_idx):
    entry_name = df[col_name].unique()[entry_idx]
    filt_statement = df[col_name] == entry_name
    new_df = df[filt_statement]
    return new_df

# %%
collect_stats = {}
for sheet_df_name, df in stats.items():
    print(f"=== SHEET NAME: {sheet_df_name} ===")
    pragmatic_tag_col_names = many_to_one_df.columns.to_list()[:-2]
    collect_stats_per_df = {}
    for pragmatic_tag_col_name in pragmatic_tag_col_names: 
        per_prag_tags = []
        print(pragmatic_tag_col_name)
        entries = many_to_one_df[pragmatic_tag_col_name].unique()
        print(f" {entries}")
        for entries_idx in range(len(entries)):
            many_to_one_statement_df = separate_by_entry(many_to_one_df, pragmatic_tag_col_name, entries_idx)
            # store_stats = {
            #     f'{sheet_df_name}-{pragmatic_tag_col_name}-{entries[entries_idx]}': len(many_to_one_statement_df)
            # }
            store_stats_per_prag_tag_entry = {
                f'{entries[entries_idx]}': len(many_to_one_statement_df)
            }
            # print(f"Per entry: {store_stats_per_prag_tag_entry}")
            per_prag_tags.append(store_stats_per_prag_tag_entry)
        # print(per_prag_tags)
        collect_stats_per_df[f'{sheet_df_name}-{pragmatic_tag_col_name}'] = per_prag_tags
        # print(collect_stats_per_df)
    collect_stats[f"{sheet_df_name}_stats"] = collect_stats_per_df
    print(collect_stats)
# Out:
# === SHEET NAME: 1-M_df ===
# AUD_SIZE
#  ['INDIVIDUAL' 'SMALL GROUP' 'LARGE GROUP']
# STATUS
#  ['EQUAL' nan]
# AGE
#  ['PEER' 'ELDER' 'YOUNGER']
# FORMALITY
#  ['INFORMAL' 'FORMAL']
# GENDER
#  ['NEUTRAL' 'MASCULINE' 'FEMININE']
# GENDER.1
#  ['NEUTRAL' nan 'FEMININE' 'MASCULINE']
# ANIMACY
#  ['ANIMATE' 'INANIMATE']
# SPEECH_ACT
#  ['STATEMENT' 'ANSWER' 'QUESTION' 'COMMAND' 'REQUEST']
# {'1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}}
# === SHEET NAME: M-1_df ===
# AUD_SIZE
#  ['INDIVIDUAL' 'SMALL GROUP' 'LARGE GROUP']
# STATUS
#  ['EQUAL' nan]
# AGE
#  ['PEER' 'ELDER' 'YOUNGER']
# FORMALITY
#  ['INFORMAL' 'FORMAL']
# GENDER
#  ['NEUTRAL' 'MASCULINE' 'FEMININE']
# GENDER.1
#  ['NEUTRAL' nan 'FEMININE' 'MASCULINE']
# ANIMACY
#  ['ANIMATE' 'INANIMATE']
# SPEECH_ACT
#  ['STATEMENT' 'ANSWER' 'QUESTION' 'COMMAND' 'REQUEST']
# {'1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, 'M-1_df_stats': {'M-1_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], 'M-1_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], 'M-1_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], 'M-1_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], 'M-1_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], 'M-1_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], 'M-1_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], 'M-1_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}}
# === SHEET NAME: 1-M_df_stats ===
# AUD_SIZE
#  ['INDIVIDUAL' 'SMALL GROUP' 'LARGE GROUP']
# STATUS
#  ['EQUAL' nan]
# AGE
#  ['PEER' 'ELDER' 'YOUNGER']
# FORMALITY
#  ['INFORMAL' 'FORMAL']
# GENDER
#  ['NEUTRAL' 'MASCULINE' 'FEMININE']
# GENDER.1
#  ['NEUTRAL' nan 'FEMININE' 'MASCULINE']
# ANIMACY
#  ['ANIMATE' 'INANIMATE']
# SPEECH_ACT
#  ['STATEMENT' 'ANSWER' 'QUESTION' 'COMMAND' 'REQUEST']
# {'1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, 'M-1_df_stats': {'M-1_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], 'M-1_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], 'M-1_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], 'M-1_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], 'M-1_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], 'M-1_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], 'M-1_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], 'M-1_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, '1-M_df_stats_stats': {'1-M_df_stats-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df_stats-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df_stats-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df_stats-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df_stats-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df_stats-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df_stats-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df_stats-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}}
# === SHEET NAME: M-1_df_stats ===
# AUD_SIZE
#  ['INDIVIDUAL' 'SMALL GROUP' 'LARGE GROUP']
# STATUS
#  ['EQUAL' nan]
# AGE
#  ['PEER' 'ELDER' 'YOUNGER']
# FORMALITY
#  ['INFORMAL' 'FORMAL']
# GENDER
#  ['NEUTRAL' 'MASCULINE' 'FEMININE']
# GENDER.1
#  ['NEUTRAL' nan 'FEMININE' 'MASCULINE']
# ANIMACY
#  ['ANIMATE' 'INANIMATE']
# SPEECH_ACT
#  ['STATEMENT' 'ANSWER' 'QUESTION' 'COMMAND' 'REQUEST']
# {'1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, 'M-1_df_stats': {'M-1_df-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], 'M-1_df-STATUS': [{'EQUAL': 3}, {'nan': 0}], 'M-1_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], 'M-1_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], 'M-1_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], 'M-1_df-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], 'M-1_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], 'M-1_df-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, '1-M_df_stats_stats': {'1-M_df_stats-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], '1-M_df_stats-STATUS': [{'EQUAL': 3}, {'nan': 0}], '1-M_df_stats-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], '1-M_df_stats-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], '1-M_df_stats-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], '1-M_df_stats-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], '1-M_df_stats-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], '1-M_df_stats-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}, 'M-1_df_stats_stats': {'M-1_df_stats-AUD_SIZE': [{'INDIVIDUAL': 363}, {'SMALL GROUP': 19}, {'LARGE GROUP': 18}], 'M-1_df_stats-STATUS': [{'EQUAL': 3}, {'nan': 0}], 'M-1_df_stats-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}], 'M-1_df_stats-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}], 'M-1_df_stats-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}], 'M-1_df_stats-GENDER.1': [{'NEUTRAL': 325}, {'nan': 0}, {'FEMININE': 32}, {'MASCULINE': 41}], 'M-1_df_stats-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}], 'M-1_df_stats-SPEECH_ACT': [{'STATEMENT': 300}, {'ANSWER': 1}, {'QUESTION': 71}, {'COMMAND': 27}, {'REQUEST': 1}]}}

# %%
collect_stats
# Out:
# {'1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363},
#    {'SMALL GROUP': 19},
#    {'LARGE GROUP': 18}],
#   '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}],
#   '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}],
#   '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}],
#   '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}],
#   '1-M_df-GENDER.1': [{'NEUTRAL': 325},
#    {'nan': 0},
#    {'FEMININE': 32},
#    {'MASCULINE': 41}],
#   '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}],
#   '1-M_df-SPEECH_ACT': [{'STATEMENT': 300},
#    {'ANSWER': 1},
#    {'QUESTION': 71},
#    {'COMMAND': 27},
#    {'REQUEST': 1}]},
#  'M-1_df_stats': {'M-1_df-AUD_SIZE': [{'INDIVIDUAL': 363},
#    {'SMALL GROUP': 19},
#    {'LARGE GROUP': 18}],
#   'M-1_df-STATUS': [{'EQUAL': 3}, {'nan': 0}],
#   'M-1_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}],
#   'M-1_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}],
#   'M-1_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}],
#   'M-1_df-GENDER.1': [{'NEUTRAL': 325},
#    {'nan': 0},
#    {'FEMININE': 32},
#    {'MASCULINE': 41}],
#   'M-1_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}],
#   'M-1_df-SPEECH_ACT': [{'STATEMENT': 300},
#    {'ANSWER': 1},
#    {'QUESTION': 71},
#    {'COMMAND': 27},
#    {'REQUEST': 1}]}}

# %%
stats.update(collect_stats)
stats
# Out:
# {'1-M_df':         AUD_SIZE  STATUS   AGE FORMALITY     GENDER   GENDER_2    ANIMACY  \
#  0     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
#  1     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE  MASCULINE    ANIMATE
#  2     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE   FEMININE    ANIMATE
#  3     INDIVIDUAL     NaN  PEER  INFORMAL  MASCULINE   FEMININE    ANIMATE
#  4     INDIVIDUAL     NaN  PEER  INFORMAL   FEMININE  MASCULINE    ANIMATE
#  ..           ...     ...   ...       ...        ...        ...        ...
#  458   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
#  459   INDIVIDUAL     NaN  PEER    FORMAL    NEUTRAL    NEUTRAL  INANIMATE
#  460  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#  461  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#  462  SMALL GROUP     NaN  PEER  INFORMAL    NEUTRAL    NEUTRAL    ANIMATE
#
#      SPEECH_ACT                                Akan (Source, One)  \
#  0    STATEMENT                             Anadwo biara ɔfrɛ no.
#  1    STATEMENT                             Anadwo biara ɔfrɛ no.
#  2    STATEMENT                             Anadwo biara ɔfrɛ no.
#  3    STATEMENT                             Anadwo biara ɔfrɛ no.
#  4    STATEMENT                              Anɔpa yi, ohyiaa no.
#  ..         ...                                               ...
#  458  STATEMENT                            Nokwarem no, osu bɛtɔ.
#  459  STATEMENT                            Nokwarem no, osu bɛtɔ.
#  460  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#  461  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#  462  STATEMENT  Ɛsɛ sɛ yehu akokoaa foforo bi a wɔawo no foforo.
#
#                            English (Target, Many)
#  0                      He calls her every night.
#  1                      He calls him every night.
#  2                     She calls her every night.
#  3                      He calls her every night.
#  4                      She met him this morning.
#  ..                                           ...
#  458              It is definitely going to rain.
#  459                   Rain is surely on the way.
#  460          We've got to find a new babysitter.
#  461      We need to look for another babysitter.
#  462  It is necessary we find another babysitter.
#
#  [463 rows x 10 columns],
#  'M-1_df':        AUD_SIZE STATUS    AGE FORMALITY     GENDER GENDER.1  ANIMACY  \
#  0    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  1    INDIVIDUAL  EQUAL   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  2    INDIVIDUAL  EQUAL   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  3    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
#  4    INDIVIDUAL    NaN   PEER    FORMAL  MASCULINE      NaN  ANIMATE
#  ..          ...    ...    ...       ...        ...      ...      ...
#  395  INDIVIDUAL    NaN  ELDER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  396  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  397  INDIVIDUAL    NaN   PEER  INFORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  398  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#  399  INDIVIDUAL    NaN   PEER    FORMAL    NEUTRAL  NEUTRAL  ANIMATE
#
#      SPEECH_ACT       Akan (Source, Many)    English (Target, One)
#  0    STATEMENT            Me na mewɔ ha.           I belong here.
#  1       ANSWER       Me fata sɛ mewɔ ha.           I belong here.
#  2    STATEMENT              Ha na me wɔ.           I belong here.
#  3    STATEMENT       Kwaku to dwom yiye.  Kwaku sings quite well.
#  4    STATEMENT        Kwaku nim nwom to.  Kwaku sings quite well.
#  ..         ...                       ...                      ...
#  395   QUESTION             Ne su te sɛn?          What's it like?
#  396  STATEMENT       Na minhu nea menyɛ.      I ran out of ideas.
#  397  STATEMENT           Me nsusuiɛ asa.      I ran out of ideas.
#  398  STATEMENT   Menni adwene biara bio.      I ran out of ideas.
#  399  STATEMENT  Menni tirimpɔ biara bio.      I ran out of ideas.
#
#  [400 rows x 10 columns],
#  '1-M_df_stats': {'1-M_df-AUD_SIZE': [{'INDIVIDUAL': 363},
#    {'SMALL GROUP': 19},
#    {'LARGE GROUP': 18}],
#   '1-M_df-STATUS': [{'EQUAL': 3}, {'nan': 0}],
#   '1-M_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}],
#   '1-M_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}],
#   '1-M_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}],
#   '1-M_df-GENDER.1': [{'NEUTRAL': 325},
#    {'nan': 0},
#    {'FEMININE': 32},
#    {'MASCULINE': 41}],
#   '1-M_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}],
#   '1-M_df-SPEECH_ACT': [{'STATEMENT': 300},
#    {'ANSWER': 1},
#    {'QUESTION': 71},
#    {'COMMAND': 27},
#    {'REQUEST': 1}]},
#  'M-1_df_stats': {'M-1_df-AUD_SIZE': [{'INDIVIDUAL': 363},
#    {'SMALL GROUP': 19},
#    {'LARGE GROUP': 18}],
#   'M-1_df-STATUS': [{'EQUAL': 3}, {'nan': 0}],
#   'M-1_df-AGE': [{'PEER': 361}, {'ELDER': 25}, {'YOUNGER': 14}],
#   'M-1_df-FORMALITY': [{'INFORMAL': 202}, {'FORMAL': 198}],
#   'M-1_df-GENDER': [{'NEUTRAL': 288}, {'MASCULINE': 83}, {'FEMININE': 29}],
#   'M-1_df-GENDER.1': [{'NEUTRAL': 325},
#    {'nan': 0},
#    {'FEMININE': 32},
#    {'MASCULINE': 41}],
#   'M-1_df-ANIMACY': [{'ANIMATE': 364}, {'INANIMATE': 36}],
#   'M-1_df-SPEECH_ACT': [{'STATEMENT': 300},
#    {'ANSWER': 1},
#    {'QUESTION': 71},
#    {'COMMAND': 27},
#    {'REQUEST': 1}]}}

# %%
import matplotlib.pyplot as plt

# Convert nested dictionary to DataFrame
def convert_to_dataframe(stats_dict, prefix):
    rows = []
    for category, items in stats_dict.items():
        for item in items:
            for key, value in item.items():
                rows.append({'Category': category.replace(prefix, ''), 'SubCategory': key, 'Value': value})
    return pd.DataFrame(rows)

df_1M = convert_to_dataframe(stats['1-M_df_stats'], '1-M_df-')
df_M1 = convert_to_dataframe(stats['M-1_df_stats'], 'M-1_df-')

# Add group identifiers
df_1M['Group'] = '1-M_df_stats'
df_M1['Group'] = 'M-1_df_stats'

# Combine both DataFrames
combined_df = pd.concat([df_1M, df_M1], ignore_index=True)
combined_df

pragmatic_tag_col_names = many_to_one_df.columns.to_list()[:-2]
collect_stats_per_df = {}
for pragmatic_tag_col_name in pragmatic_tag_col_names: 
    for entries_idx in range(len(entries)):
        df = separate_by_entry(many_to_one_df, pragmatic_tag_col_name, entries_idx)
        # Pivot to have SubCategory as columns and Group as rows
        pivot_aud_size = df.pivot(index="Group", columns="SubCategory", values="Value")

        # Plot boxplot using pandas
        plt.figure(figsize=(8, 6))
        pivot_aud_size.plot(kind="bar")
        plt.title("Boxplot for AUD_SIZE")
        plt.ylabel("Value")
        plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 29
#      27 df = separate_by_entry(many_to_one_df, pragmatic_tag_col_name, entries_idx)
#      28 # Pivot to have SubCategory as columns and Group as rows
# ---> 29 pivot_aud_size = df.pivot(index="Group", columns="SubCategory", values="Value")
#      31 # Plot boxplot using pandas
#      32 plt.figure(figsize=(8, 6))
#
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:553, in pivot(data, columns, index, values)
#     549         index_list = [
#     550             data._constructor_sliced(data.index, name=data.index.name)
#     551         ]
#     552 else:
# --> 553     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     555 data_columns = [data[col] for col in columns_listlike]
#     556 index_list.extend(data_columns)
#
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:553, in <listcomp>(.0)
#     549         index_list = [
#     550             data._constructor_sliced(data.index, name=data.index.name)
#     551         ]
#     552 else:
# --> 553     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     555 data_columns = [data[col] for col in columns_listlike]
#     556 index_list.extend(data_columns)
#
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Documents/Development/classes/cai_6307_nlp/comp_express_mt/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Group'

# %%
# Categories to iterate over
categories = combined_df["Category"].unique()

# Loop through each group and category
groups = ["1-M_df_stats", "M-1_df_stats"]

for g_idx, group in enumerate(groups):
    # Separate data for the current group
    current_df = separate_by_entry(combined_df, "Group", g_idx)
    
    for category in categories:
        # Filter for the current category
        filt_category = current_df["Category"] == category
        category_df = current_df[filt_category]
        
        # Pivot for boxplot
        pivot_df = category_df.pivot(index="Group", columns="SubCategory", values="Value")
        
        
        # Plot boxplot
        plt.figure(figsize=(8, 6))
        pivot_df.plot(kind="bar")
        plt.title(f"Bar for {category} - {group}")
        plt.ylabel("Value")
        plt.xticks(rotation=45)
        plt.show()

# %%
# Convert to DataFrames
df_1M = convert_to_dataframe(stats['1-M_df_stats'], '1-M_df-')
df_M1 = convert_to_dataframe(stats['M-1_df_stats'], 'M-1_df-')

# Add group identifiers
df_1M['Group'] = '1-M_df_stats'
df_M1['Group'] = 'M-1_df_stats'

# Combine both DataFrames
combined_df = pd.concat([df_1M, df_M1], ignore_index=True)

# Step 2: Split into separate DataFrames by Category and append to a list
category_list = combined_df['Category'].unique()
df_list = [combined_df[combined_df['Category'] == cat].copy() for cat in category_list]

# Step 3: Function to join all DataFrames in the list
def join_dataframes(df_list):
    return pd.concat(df_list, ignore_index=True)

# Example usage:
final_df = join_dataframes(df_list)
print(final_df.head())
# Out:
#    Category  SubCategory  Value         Group
# 0  AUD_SIZE   INDIVIDUAL    363  1-M_df_stats
# 1  AUD_SIZE  SMALL GROUP     19  1-M_df_stats
# 2  AUD_SIZE  LARGE GROUP     18  1-M_df_stats
# 3  AUD_SIZE   INDIVIDUAL    363  M-1_df_stats
# 4  AUD_SIZE  SMALL GROUP     19  M-1_df_stats

# %%
df_list[0].plot.bar()
# Out:
# <Axes: >
